# %% [markdown]
# # Kitchen Dreams
# An Examination of the Tri-State Area Cuisine in New York Using Census and Yelp Data.

# %% [markdown]
# ![Rooftop Restaurant NYC](https://www.therooftopguide.com/rooftop-news/Bilder/rooftop-restaurant-nyc-230-1.jpg)

# %% [markdown]
# ## Table of Contents
# 1. [Abstract](#abstract)
# 2. [Introduction](#introduction)
# 3. [Research Approach](#research-approach)
# 4. [Exploratory Data Analysis (EDA)](#eda)
# 5. [Inference](#inf)
# 6. [Data Preparation](#data-preparation)
# 7. [Prepped Data Review](#prepped-data-review)
# 8. [Investigative Analysis & Results](#investigative-analysis-results)
# 9. [Conclusions](#conclusions)

# %% [markdown]
# ## Abstract <a id="abstract"></a>

# %% [markdown]
# This research investigates the complex interactions of economic, demographic, and culinary variables in the New York Tri-State region. We use Yelp data and Census information to unearth the stories behind the restaurants in the area because we are curious in how different cultures and economic levels affect dining preferences. Our study questions explore the following topics: how geography affects Yelp reviews; how economic status and restaurant kinds are correlated; how demographic considerations affect restaurant success; where are the best places for new businesses to open; and how popularity, pricing, and ratings relate to each other.
#
# Using the Yelp API for restaurant details and Census.gov for demographic and economic data, the process entails a thorough collection of data. Our group works together to do univariate, bivariate, and multivariate analyses using Python modules such as Beautiful Soup, Pandas, Matplotlib, and Seaborn. The goal of the investigative analysis is to discover economic elements influencing culinary preferences, provide recommendations for aspiring restaurateurs based on current trends, and shed light on the relationship between restaurant ratings and demographic composition.
#
# We put a high priority on data integrity throughout the project, carry out in-depth exploratory data analysis (EDA), and apply data preparation strategies. The results include a thorough examination of how socioeconomic variables influence food choices in the New York Tri-State region, a sophisticated grasp of the culinary environment, and practical advice for restaurant owners. This project exemplifies how to combine extensive data sources with Python's analytical powers to unravel the complexity of the regional food scene.

# %% [markdown]
# ## Introduction <a id="introduction"></a>

# %% [markdown]
# This project explores the thriving culinary and eating scene in the Tri-State area of New York. It's about learning how the diverse range of cultures and economic circumstances in the area affects where and what we consume. We are going to learn the narratives behind the restaurants in the area by examining demographic data and Yelp ratings. Consider it an exploration of how the local food scene is shaped by the people and their backgrounds as you go across the areas of New York and New Jersey.
#
# 1. **Geographical Impact on Yelp Ratings:**
#    - How does the specific location within the Tri-State area influence a restaurant's Yelp rating, especially concerning particular cuisines?
#
# 2. **Economic Status and Restaurant Types:**
#    - Is there a discernible correlation between the economic status of a neighborhood and the types of restaurants it hosts?
#
# 3. **Demographic Influences on Restaurant Success:**
#    - To what extent do demographic factors, such as ethnic composition, contribute to the success of various restaurant types?
#
# 4. **Optimal Locations for New Restaurants:**
#    - What are the current trends, and where are the optimal locations for opening new restaurants based on these trends?
#
# 5. **Cuisine Pricing, Ratings, and Popularity:**
#    - How is the pricing of different cuisines related to their Yelp ratings and overall popularity in the Tri-State area?
#
# In exploring these questions, we aim to uncover the unique narratives behind the diverse restaurants that populate the Tri-State area, offering insights into how the local food scene is intricately woven into the fabric of its people and their backgrounds.

# %% [markdown]
# ## Expected Results
#
# - Information on how restaurant ratings and demographic composition relate to one another.
# - Determining the economic variables affecting taste in food.
# - Suggestions for potential restaurateurs regarding the locations of new businesses.
#
# ## Timetable
#
# **Week 1:** Gathering data and integrating APIs.
#
# **Week 2:** Cleaning data and conducting preliminary analysis.
#
# **Week 3:** Comprehensive data visualization and analysis.
#
# **Week 4:** Report assembly and delivery.
#
# ## Importance & Inspiration for Research
#
# Restaurant owners, food fans, and culinary specialists will all gain from this study's insightful analysis of the sociodemographically driven gastronomic tastes of the New York Tri-State region.

# %% [markdown]
# ## Research Approach <a id="research-approach"></a>

# %% [markdown]
# #### Data Collection:
#
# - **Yelp API:** To gather data on restaurant ratings, cuisine types, pricing, and customer reviews from the New York Tri-State area. [Yelp API Documentation](https://docs.developer.yelp.com/docs/fusion-intro)
#   - Restaurants will be of different cuisine categories, must have mixed ratings on Yelp, and a '$$' price tag.
#
# - **Census.gov (CSV):** To obtain demographic and economic data for the same region, enabling a comprehensive analysis of how these factors relate to food preferences and restaurant success. [Census Data for New York Tri-State Area](https://www.census.gov/quickfacts/fact/table/bergencountynewjersey,richmondcountynewyork,bronxcountynewyork,queenscountynewyork,kingscountynewyork,newyorkcountynewyork/PST045222)
#
#   - **Data Cleaning File:**
#     - Created an Excel file for data cleaning, containing essential variables such as rating, price, zip_code, categories, cuisine, and borough. This file facilitated the initial stages of data preparation and ensured consistency across relevant attributes.

# %% [markdown]
# #### Approach to Data Management:
#
# - **Version Control:** Git version control was used to keep track of changes, facilitate productive collaboration, and preserve an unambiguous project history.
# - **Data Storage:** Organized directories to facilitate easy access and replication for both raw and processed data.
# - **Documentation:** Transparency and reproducibility are ensured by recording data sources, preparation steps, and analytic procedures in Markdown cells.
# - **Collaboration:** Promoted teamwork by utilizing technologies that made it easy to share and update analysis and code.
#
# #### Investigative Data Examination:
# - Used Python libraries (Pandas, Matplotlib, Seaborn) to conduct thorough EDA.
# - Looked for trends and connections in the distribution of restaurant ratings, cuisine categories, and pricesncy.

# %% [markdown]
# ## Exploratory Data Analysis (EDA) <a id="eda"></a>

# %% [markdown]
# ### Getting Yelp Data from API

# %%
# Import the function from the yelpapi.py script
from src.restaurant_analysis.yelpapi import get_restaurant_data

# Define the list of locations and cuisines
locations = ['Brooklyn, NY', 'Queens, NY', 'Staten Island, NY', 'The Bronx, NY']
cuisines = ['Italian', 'American', 'Japanese', 'Mexican', 'Kosher']

# Call the function with the desired parameters, and save the data to a CSV file
csv_file_path = 'restaurants_data.csv'  # Specify the path for the CSV file
restaurant_data = get_restaurant_data(locations, cuisines, save_csv=True, csv_file_path=csv_file_path)

# Inform the user
print(f"Data collection complete and saved to {csv_file_path}")
restaurant_data
# Out:
# Data collection complete and saved to restaurants_data.csv
# [{'name': 'Osteria Brooklyn',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11205',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Forma Pasta Factory',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Italian, Pasta Shops, Salad',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Evelina',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11205',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Piccoli Trattoria',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Italian, Pasta Shops, Wine Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Positano Restaurant',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11209',
#   'categories': 'Italian, Gluten-Free, Seafood',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Botte Brooklyn',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11201',
#   'categories': 'Italian, Pizza',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Michael's of Brooklyn",
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11229',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Da Andrea - Greenwich Village',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10011',
#   'categories': 'Italian, Mediterranean, Breakfast & Brunch',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Cent'Anni",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Montesacro Pinseria Brooklyn',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Italian, Pizza, Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Gino's Brick Oven Pizza & Trattoria",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11225',
#   'categories': 'Italian, Pizza, Wine Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Il Posto',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11234',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Lillo Cucina Italiana',
#   'rating': 5.0,
#   'price': '$$',
#   'zip_code': '11201',
#   'categories': 'Cafes, Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Macosa Trattoria',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11216',
#   'categories': 'Italian, Comfort Food',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Barbalu - Brooklyn',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11201',
#   'categories': 'Italian, Pizza, Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Ammazzacaffè',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Cocktail Bars, Italian, Wine Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Rustico Taverna',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11385',
#   'categories': 'Italian, Pizza',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Camillo',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11225',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Scottadito Osteria Toscana',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11215',
#   'categories': 'Italian, Venues & Event Spaces',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Aita Trattoria',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Italian, Wine Bars, Cocktail Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Fragole Ristorante',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11231',
#   'categories': 'Italian, Wine Bars, Cocktail Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Da Nonna Rosa',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Italian, Pizza, Venues & Event Spaces',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mariella',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Italian, Gluten-Free, Salad',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Il Colosseo',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11214',
#   'categories': 'Italian, Pizza',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Santa Panza',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11221',
#   'categories': 'Pizza, Italian, Breakfast & Brunch',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "L'Artusi",
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '10014',
#   'categories': 'Italian, Cocktail Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Concrete Brooklyn',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11206',
#   'categories': 'Bars, Italian, Venues & Event Spaces',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mama Rao Cucina Italiana',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11219',
#   'categories': 'Italian, Party & Event Planning',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Brooklyn Roots Italian',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11209',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Loreto Italian Kitchen & Bar',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11217',
#   'categories': 'Lounges, Italian, Wine Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Saraghina Pizzeria',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11233',
#   'categories': 'Pizza, Italian, Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Locanda Vini e Olii',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11238',
#   'categories': 'Italian, Wine Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Barboncino Pizza & Bar',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Pizza, Bars, Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Lilia',
#   'rating': 4.0,
#   'price': '$$$$',
#   'zip_code': '11211',
#   'categories': 'Italian, Cocktail Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Aurora',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11249',
#   'categories': 'Italian, Comfort Food',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Ferdinando's Focacceria",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11231',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Gersi',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11231',
#   'categories': 'Italian, Wine Bars, Breakfast & Brunch',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Bamonte's",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Testo',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11206',
#   'categories': 'Italian, Gluten-Free, Breakfast & Brunch',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Olio e Più',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10014',
#   'categories': 'Pizza, Italian, Cocktail Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Juliana's",
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11201',
#   'categories': 'Pizza',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Roberta's",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11206',
#   'categories': 'Pizza, Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Don Angie',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '10014',
#   'categories': 'Italian, New American',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Forma Pasta Factory',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11222',
#   'categories': 'Pasta Shops, Italian, Salad',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Graziella's",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11205',
#   'categories': 'Italian, Pizza, Bars',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'La Villa',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Italian, Pizza, Sandwiches',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Gargiulo's",
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '11224',
#   'categories': 'Italian, Venues & Event Spaces, Seafood',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Rubirosa',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10012',
#   'categories': 'Italian, Pizza',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Bonafini',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11225',
#   'categories': 'Breakfast & Brunch, Italian',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Terre',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11215',
#   'categories': 'Italian, Wine Bars, Breakfast & Brunch',
#   'cuisine': 'Italian',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Arden',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11238',
#   'categories': 'New American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Three Maples',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11216',
#   'categories': 'Burgers, Cocktail Bars, New American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'The Brooklyn Tree',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11206',
#   'categories': 'Comfort Food, New American, Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'South Brooklyn Foundry',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11209',
#   'categories': 'New American, Breakfast & Brunch, Burgers',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Concrete',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11206',
#   'categories': 'Bars, Breakfast & Brunch, Sicilian',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Westville',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11211',
#   'categories': 'Salad, New American, Cocktail Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Milk & Honey Cafe',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11230',
#   'categories': 'Coffee & Tea, Desserts, Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Walter's",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'New American, Cocktail Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'The Wheelhouse',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11237',
#   'categories': 'New American, Sandwiches, Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Buttermilk Channel',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11231',
#   'categories': 'Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Sweet Brooklyn Bar And Grill',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11216',
#   'categories': 'Gastropubs, American, Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'DIG',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11201',
#   'categories': 'New American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Charm Bar & Restaurant',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11217',
#   'categories': 'Caribbean, New American, Cocktail Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Lincoln Station',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'American, Cafes',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'The Cabin NYC',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10009',
#   'categories': 'New American, Cocktail Bars, Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Otis',
#   'rating': 5.0,
#   'price': '$$$',
#   'zip_code': '11206',
#   'categories': 'New American, Cocktail Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Midwood Flats',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11225',
#   'categories': 'Cocktail Bars, Pubs, Bartenders',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Emily',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Sunday in Brooklyn',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11249',
#   'categories': 'New American, Breakfast & Brunch, Cocktail Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mama Fox',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11233',
#   'categories': 'New American, Cocktail Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Bonnie's Grill",
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11215',
#   'categories': 'Chicken Wings, Burgers, American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Flatiron Restaurant',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11215',
#   'categories': 'Steakhouses, Burgers, Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Peaches HotHouse',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11216',
#   'categories': 'Southern, American, Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'no. 7',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11238',
#   'categories': 'New American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Hart's Restaurant",
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11238',
#   'categories': 'New American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Sailor',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11205',
#   'categories': 'New American, Wine Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Sweet Chick',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Breakfast & Brunch, Southern, Chicken Shop',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'J&A Burgers N Shakes',
#   'rating': 3.5,
#   'price': '$',
#   'zip_code': '11237',
#   'categories': 'Burgers, Wraps',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Mom's Kitchen & Bar",
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10019',
#   'categories': 'Comfort Food, Breakfast & Brunch, Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Sea Wolf - Bushwick',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11237',
#   'categories': 'Cocktail Bars, Seafood, American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Peaches',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '11233',
#   'categories': 'Southern, Seafood, Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mayfield',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'New American, Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Nura',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11222',
#   'categories': 'New American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Tong',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11237',
#   'categories': 'Thai, Bars, Tapas/Small Plates',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Baron's",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11205',
#   'categories': 'New American, Bars, Seafood',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Sweetwater Restaurant',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11249',
#   'categories': 'New American, Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'The Four Horsemen',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Wine Bars, New American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Endswell Bar & Bistro',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Cocktail Bars, French',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Honey Badger',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11225',
#   'categories': 'New American, Seafood',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Ingas Bar',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11201',
#   'categories': 'New American',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Stocked Burger',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11238',
#   'categories': 'Burgers',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Da Andrea - Greenwich Village',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10011',
#   'categories': 'Italian, Mediterranean, Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Ruthie's",
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11231',
#   'categories': 'New American, Salad, Burgers',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Antidote',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11249',
#   'categories': 'Cocktail Bars, Dim Sum, Szechuan',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Black Oak on Fifth',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11217',
#   'categories': 'New American, Italian, Cocktail Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Bijan's",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'New American, Cocktail Bars, Mediterranean',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Five Leaves',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11222',
#   'categories': 'New American, Coffee & Tea, Bars',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Pomo',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11201',
#   'categories': 'Cocktail Bars, Mexican',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Venus Restaurant',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11226',
#   'categories': 'New American, Haitian',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Tom's",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Diners, American, Breakfast & Brunch',
#   'cuisine': 'American',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Ozakaya',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11238',
#   'categories': 'Izakaya, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'SOBOKU',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11231',
#   'categories': 'Japanese',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Fujisawa Asian Bistro',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11235',
#   'categories': 'Asian Fusion, Sushi Bars, Ramen',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Verge',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11222',
#   'categories': 'Sushi Bars, Japanese, Asian Fusion',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Osaka Fusion Sushi',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11214',
#   'categories': 'Japanese, Sushi Bars, Seafood',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Okonomi',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11211',
#   'categories': 'Japanese, Seafood',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Trad Room',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11233',
#   'categories': 'Japanese, Sushi Bars, Cocktail Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Izakaya Nana',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11354',
#   'categories': 'Izakaya',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Oita NYC',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Sushi Bars, Japanese, Asian Fusion',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Fukurou Brooklyn',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11237',
#   'categories': 'Ramen',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mikado',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11201',
#   'categories': 'Japanese, Sushi Bars, Soup',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Dashi Okume',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11222',
#   'categories': 'Japanese',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'IWak',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11211',
#   'categories': 'Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Sushi Yashin',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Japanese, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Izakaya Fuku',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11372',
#   'categories': 'Japanese',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Wasan Brooklyn',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Japanese',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Omakase Sushi By Hiro',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11235',
#   'categories': 'Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'A-un Brooklyn',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11237',
#   'categories': 'Japanese, Beer Bar',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Warude Crown Heights',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11216',
#   'categories': 'Ramen, Salad, Japanese Curry',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'ACRE',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11222',
#   'categories': 'Breakfast & Brunch, Japanese, Coffee & Tea',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Rule of Thirds',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11222',
#   'categories': 'Japanese, Breakfast & Brunch, Cocktail Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Ako',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Sushi Bars, Japanese, Wine Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'U-gu',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11205',
#   'categories': 'Sushi Bars, Japanese',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Izakaya Ajimi',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11214',
#   'categories': 'Izakaya, Ramen',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': '750 Myrtle Diner',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11205',
#   'categories': 'Tapas Bars, Izakaya',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Raku',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10003',
#   'categories': 'Japanese, Noodles',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Menya & Izakaya',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Ramen, Noodles',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Geido',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Japanese, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Uotora',
#   'rating': 4.5,
#   'price': '$$$$',
#   'zip_code': '11216',
#   'categories': 'Japanese, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Tonchin',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11249',
#   'categories': 'Ramen, Salad, Seafood',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Karasu',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11217',
#   'categories': 'Japanese, Cocktail Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Chuko',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Asian Fusion, Ramen',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Gen',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Japanese, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Za-Ya',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11237',
#   'categories': 'Ramen, Noodles',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Omatoya',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11378',
#   'categories': 'Sushi Bars, Japanese',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Kimura',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '10003',
#   'categories': 'Japanese, Hot Pot, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Nami Nori',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11211',
#   'categories': 'Sushi Bars, Japanese, Gluten-Free',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Silver Rice',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Japanese, Sushi Bars, Soup',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Ishi Omakase & Premium Sake',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11217',
#   'categories': 'Japanese, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Ume Williamsburg',
#   'rating': 4.0,
#   'price': '$$$$',
#   'zip_code': '11249',
#   'categories': 'Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mirakuya - Brooklyn',
#   'rating': 4.0,
#   'price': '$',
#   'zip_code': '11206',
#   'categories': 'Japanese',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Lingo',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11222',
#   'categories': 'New American, Japanese',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': '1 OR 8',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11205',
#   'categories': 'Japanese, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'To Date Japanese Food',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11220',
#   'categories': 'Japanese, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Bushniwa',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11206',
#   'categories': 'Japanese, Sushi Bars, Asian Fusion',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Hibino',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11201',
#   'categories': 'Japanese, Sushi Bars',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Kosan Asian Fusion',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11235',
#   'categories': 'Asian Fusion, Sushi Bars, Poke',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Karazishi Botan',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11231',
#   'categories': 'Ramen',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Kanji Sushi Hibachi - Ridgewood',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11385',
#   'categories': 'Sushi Bars, Japanese, Asian Fusion',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'The Garden At Ditmas',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11218',
#   'categories': 'Ramen',
#   'cuisine': 'Japanese',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Chavela's",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Mexican, Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Chela Park Slope',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Mexican, Cocktail Bars, Breakfast & Brunch',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Cruz Del Sur',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Tacos, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Taqueria Milear',
#   'rating': 4.0,
#   'price': '$',
#   'zip_code': '11216',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Taqueria El Patron',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11385',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Casa Azul',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Mexican, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'De Mole',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11211',
#   'categories': 'Mexican, Breakfast & Brunch, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Martha's Cocina Mexicana",
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11238',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Taqueria El Patron Mexican Grill Park Slope',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11215',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'El Jeffe',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11216',
#   'categories': 'New Mexican Cuisine',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Panchitas Place',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11215',
#   'categories': 'Bars, Breakfast & Brunch, Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Breuklyn Tequila & Taco Bar',
#   'rating': 3.5,
#   'price': 'Not Available',
#   'zip_code': '11216',
#   'categories': 'Tacos, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Taqueria El Patron Mexican Grill',
#   'rating': 3.5,
#   'price': '$$$',
#   'zip_code': '11225',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Gordo's Cantina",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11237',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Las Chelitas',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11228',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Amaranto Mexican Restaurant',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11237',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Nacho Macho Taco',
#   'rating': 4.5,
#   'price': '$',
#   'zip_code': '11217',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Casa Maya',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11221',
#   'categories': 'Mexican, Cocktail Bars, Dance Clubs',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Las Santas',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Mexican, Cocktail Bars, Breakfast & Brunch',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Calabrije's Margaritas & Tacos",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11237',
#   'categories': 'Tacos, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Oxomoco',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11222',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Luisa Cocina Mexicana',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11237',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Los Tres Chiflados',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11226',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Tacombi',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Tacombi',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Miti Miti',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Latin American, Mexican, Breakfast & Brunch',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Xixa',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11211',
#   'categories': 'Mexican, Tapas/Small Plates, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Jajaja Mexicana',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11249',
#   'categories': 'Mexican, Vegan, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Caliza',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10013',
#   'categories': 'Cocktail Bars, Mexican, Breakfast & Brunch',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Don Pancho Villa Restaurant',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Tex-Mex, Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mesa Azteca',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11237',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Taqueria Al Pastor',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11201',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Jauja Mexican Kitchen',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11225',
#   'categories': 'Tacos',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Fonda Park Slope',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11215',
#   'categories': 'Mexican, Salad, Breakfast & Brunch',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Bar Verde',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10003',
#   'categories': 'Mexican, Vegan, Gluten-Free',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mesa Coyoacan',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Mexican, Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Nacho Macho Taco',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Fonda Garibaldi',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11219',
#   'categories': 'New Mexican Cuisine',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'El Zason',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'El Caminante',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11221',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Rosa Mexicano',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10003',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Jajaja Mexicana',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10002',
#   'categories': 'Mexican, Vegan, Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'BK Taco Factory',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11237',
#   'categories': 'Tacos, Seafood',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Don Patron Bar & Grill',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11218',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Jajaja Mexicana',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10014',
#   'categories': 'Mexican, Vegan, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Chilo's",
#   'rating': 4.0,
#   'price': '$',
#   'zip_code': '11238',
#   'categories': 'Bars, Mexican, Food Trucks',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Ho' Brah a Taco Joint",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11209',
#   'categories': 'Mexican, Cocktail Bars, Hawaiian',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Maya Taqueria',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11215',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Cinco de Mayo Mexican Restaurant',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11218',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Citrico',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11238',
#   'categories': 'Mexican, Breakfast & Brunch, Vegan',
#   'cuisine': 'Mexican',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Bou'ote",
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '11213',
#   'categories': 'Kosher, Cocktail Bars',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Carbon Charcoal Grill & Bar',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11213',
#   'categories': 'Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mama Kitchen',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11233',
#   'categories': 'Kosher, Middle Eastern',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Izzy's Brooklyn Smokehouse",
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11213',
#   'categories': 'Barbeque, Kosher, Smokehouse',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Miriam',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Wine Bars, Mediterranean, Breakfast & Brunch',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Traif',
#   'rating': 4.5,
#   'price': '$$$$',
#   'zip_code': '11211',
#   'categories': 'New American, Tapas/Small Plates',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': "David's Restaurant",
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11223',
#   'categories': 'Kosher, Middle Eastern',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': "David's Brisket House and Deli",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11216',
#   'categories': 'Delis, Sandwiches, Burgers',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Milk & Honey Cafe',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11230',
#   'categories': 'Coffee & Tea, Desserts, Breakfast & Brunch',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Ital Kitchen',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11225',
#   'categories': 'Vegetarian, Vegan',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Barnea Bistro',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '10017',
#   'categories': 'French, Wine Bars, Beer Bar',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Bunna Cafe',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11237',
#   'categories': 'Ethiopian, Vegan, African',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Meat Cafe',
#   'rating': 3.5,
#   'price': 'Not Available',
#   'zip_code': '11213',
#   'categories': 'Kosher, Steakhouses, Cocktail Bars',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'ALENbi',
#   'rating': 3.5,
#   'price': '$$$$',
#   'zip_code': '11225',
#   'categories': 'Middle Eastern, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Boeuf & Bun',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '11213',
#   'categories': 'Burgers',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'The Loft Steakhouse',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11218',
#   'categories': 'Steakhouses, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Reunion',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Breakfast & Brunch, Middle Eastern, Cocktail Bars',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Shiraz Kitchen & Wine Bar',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '10011',
#   'categories': 'Persian/Iranian, Wine Bars, Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Yemen Cafe & Restaurant',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11201',
#   'categories': 'Middle Eastern, Cafes, Soup',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Bordeaux',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11230',
#   'categories': 'Kosher, Steakhouses, New American',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Malka NYC',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10023',
#   'categories': 'Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Abaita',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '10017',
#   'categories': 'Mediterranean, Kosher, Pizza',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'The Bay Cafe',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11235',
#   'categories': 'Cafes, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Greenwich and Delancey',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10006',
#   'categories': 'Kosher, Soup, Sandwiches',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Bison & Bourbon',
#   'rating': 3.0,
#   'price': '$$$$',
#   'zip_code': '11215',
#   'categories': 'Kosher, Burgers, American',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'T Fusion Steakhouse',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11234',
#   'categories': 'Steakhouses, Kosher, Venues & Event Spaces',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Munch Street Food',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11230',
#   'categories': 'Kosher, Fast Food',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Gruit',
#   'rating': 3.5,
#   'price': 'Not Available',
#   'zip_code': '11225',
#   'categories': 'Bars, Kosher, Beer Gardens',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': '12 Chairs Cafe',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11249',
#   'categories': 'Middle Eastern, Breakfast & Brunch, Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Karczma',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11222',
#   'categories': 'Polish',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Shalom Japan',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11211',
#   'categories': 'Japanese',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'King Solomon Glatt Kosher Catering & Reastaurant',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11230',
#   'categories': 'Kosher, Russian, Middle Eastern',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Miznon',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10011',
#   'categories': 'Mediterranean, Middle Eastern, Sandwiches',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Orchidea',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11219',
#   'categories': 'Kosher, New American',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Masuda Omakase',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10018',
#   'categories': 'Sushi Bars, Personal Chefs, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': '19 Cleveland',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10012',
#   'categories': 'Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Grill On Lee',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '11205',
#   'categories': 'Kosher, Chinese, Delis',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Essen NY Deli',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11230',
#   'categories': 'Delis, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Cork & Slice',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11516',
#   'categories': 'Pizza, Kosher, Italian',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Hapisgah',
#   'rating': 3.5,
#   'price': '$$$',
#   'zip_code': '11367',
#   'categories': 'Kosher, Steakhouses',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Luanne's Wild Ginger",
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11205',
#   'categories': 'Vegan, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Oshi's Cafe",
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11229',
#   'categories': 'Kosher, Vegetarian, Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Zula Grill',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '07631',
#   'categories': 'Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Gertie',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11211',
#   'categories': 'Breakfast & Brunch, Cocktail Bars, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Ravagh Persian Grill',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10016',
#   'categories': 'Middle Eastern, Persian/Iranian, Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Holy Schnitzel',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11223',
#   'categories': 'Kosher, Salad, Sandwiches',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mile End Delicatessen Brooklyn',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '11217',
#   'categories': 'Delis, Breakfast & Brunch, Sandwiches',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Mint',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '11223',
#   'categories': 'New American, Seafood, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': 'Paprika Restaurant',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11021',
#   'categories': 'Kosher, Moroccan, Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Mike's Bistro",
#   'rating': 4.5,
#   'price': '$$$$',
#   'zip_code': '10022',
#   'categories': 'New American, Kosher, Bars',
#   'cuisine': 'Kosher',
#   'borough': 'Brooklyn, NY'},
#  {'name': "Trattoria L'incontro",
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11105',
#   'categories': 'Italian, Pizza, Salad',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': 'Tuscan Hills',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11375',
#   'categories': 'Italian, Pizza, Wine Bars',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': 'Park Side Restaurant',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11368',
#   'categories': 'Italian',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': 'Valdari NYC',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '11361',
#   'categories': 'Italian, Pizza, Cocktail Bars',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': 'Vite Vinosteria',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11106',
#   'categories': 'Italian, Wine Bars',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': 'Rustico Taverna',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11385',
#   'categories': 'Italian, Pizza',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': 'Trattoria 35',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11361',
#   'categories': 'Pizza, Italian',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': 'Sotto La Luna',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11106',
#   'categories': 'Italian, Pizza',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': 'Don Peppe',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '11420',
#   'categories': 'Italian, Desserts, Seafood',
#   'cuisine': 'Italian',
#   'borough': 'Queens, NY'},
#  {'name': "Bruno's Ristorante",
#   'rating': 4.5,
# ...
#  {'name': 'Cocina Chente',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Mexican, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'La Catrina Mexican Bistro',
#   'rating': 3.5,
#   'price': 'Not Available',
#   'zip_code': '10034',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': "Little Frida's Eatery",
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10464',
#   'categories': 'Mexican, American',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Tulcingo Cafe',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '10461',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': "Frida's Tacos",
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10471',
#   'categories': 'Tacos',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Don Jose Mexican Restaurant',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10710',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Tobalá',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '10463',
#   'categories': 'Mexican, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'La Catrina Mexican Bar III',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '10472',
#   'categories': 'Mexican, Bars, Event Planning & Services',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Estrellita Mixteca',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '10472',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Mama Puebla',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10465',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'el asadero Mexican grill Fort lee',
#   'rating': 3.5,
#   'price': 'Not Available',
#   'zip_code': '07024',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Havana Cafe',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10461',
#   'categories': 'Cuban, Latin American',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'La Cocina De Mama',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10029',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'The Mas Chingon',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11358',
#   'categories': 'Mexican, Diners, Breakfast & Brunch',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Cantina Lobos',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10803',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': "Yolanda's Tamales",
#   'rating': 5.0,
#   'price': '$',
#   'zip_code': '10031',
#   'categories': 'Mexican, Food Stands',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Top Tortillas',
#   'rating': 4.0,
#   'price': '$',
#   'zip_code': '10461',
#   'categories': 'Mexican, Tex-Mex',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'El Molcajete',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10472',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'El Alazan Bar Restaurant',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '07601',
#   'categories': 'Mexican, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'La Casa De Frida',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '10467',
#   'categories': 'New Mexican Cuisine, New American, Dominican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Vida Verde',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10019',
#   'categories': 'Cocktail Bars, Mexican, Venues & Event Spaces',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Rosa Mexicano',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10023',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Guadalupe Restaurant',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10034',
#   'categories': 'Mexican, Steakhouses, Seafood',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Ruta Oaxaca Mexican Cuisine',
#   'rating': 4.5,
#   'price': '$$$',
#   'zip_code': '11106',
#   'categories': 'Mexican, Breakfast & Brunch, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Pique 86',
#   'rating': 4.5,
#   'price': '$',
#   'zip_code': '10458',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Santa Fe Grill & Bar',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10471',
#   'categories': 'Mexican, Bars',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Tacos El Bronco II',
#   'rating': 4.5,
#   'price': '$',
#   'zip_code': '10462',
#   'categories': 'Mexican, Food Trucks',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'La Casa Bronxville',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10708',
#   'categories': 'Mexican, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Colima Taqueria',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '10458',
#   'categories': 'Tacos, Cocktail Bars',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Chavez Restaurant',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10467',
#   'categories': 'Tacos',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Metate',
#   'rating': 3.0,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Taqueria Guerrero',
#   'rating': 3.5,
#   'price': 'Not Available',
#   'zip_code': '10461',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Taqueria Emilio',
#   'rating': 4.5,
#   'price': '$',
#   'zip_code': '10034',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Estrellita Poblana',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '10467',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Estrellita Poblana New Roc',
#   'rating': 3.5,
#   'price': 'Not Available',
#   'zip_code': '10801',
#   'categories': 'Mexican',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Cinco De Mayo',
#   'rating': 3.5,
#   'price': '$',
#   'zip_code': '10451',
#   'categories': 'Mexican, Caterers',
#   'cuisine': 'Mexican',
#   'borough': 'The Bronx, NY'},
#  {'name': "Liebman's Kosher Delicatessen",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Delis, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Second Helping Glatt Kosher Food',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Delis',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Prime Time Cafe',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '10804',
#   'categories': 'Pizza, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Kai Fan Asian Cuisine',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Kosher, Japanese, Chinese',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Teitel Brothers',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10458',
#   'categories': 'Grocery, Imported Food',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Corner Cafe & Bakery',
#   'rating': 3.0,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Vegetarian, Bakeries, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': "Carlos & Gabby's Riverdale",
#   'rating': 3.0,
#   'price': '$$',
#   'zip_code': '10471',
#   'categories': 'Mexican, Kosher, Barbeque',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Riverdale Steak House',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10471',
#   'categories': 'Steakhouses, Irish Pub',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Moss Cafe',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Cafes, Kosher, New American',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Yo-Burger',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Burgers, Vegetarian',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Golan Heights',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10033',
#   'categories': 'Middle Eastern, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Näna Good Eats',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11357',
#   'categories': 'Middle Eastern, Falafel, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'S&S Cheesecake',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Desserts, Bakeries, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Pizza Block',
#   'rating': 2.0,
#   'price': '$$',
#   'zip_code': '10471',
#   'categories': 'Pizza, Kosher, Sushi Bars',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Hakadosh BBQ',
#   'rating': 3.5,
#   'price': '$$$',
#   'zip_code': '10704',
#   'categories': 'Specialty Food',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Foster Village Kosher Deli',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '07621',
#   'categories': 'Delis, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Veggie Heaven',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '07666',
#   'categories': 'Vegetarian, Kosher, Vegan',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Leche Y Miel Restaurant',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Comfort Food, Dominican, Juice Bars & Smoothies',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'The Wooden Spoon',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10801',
#   'categories': 'Burgers, American, Beer Bar',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Ember by Smokey Joe',
#   'rating': 3.0,
#   'price': 'Not Available',
#   'zip_code': '10471',
#   'categories': 'Steakhouses, Barbeque, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Blackstone Bar & Grill',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Sports Bars, Burgers, Sandwiches',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Paprika Restaurant',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '11021',
#   'categories': 'Kosher, Moroccan, Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Burger Heights',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10033',
#   'categories': 'Burgers, Fast Food, Hot Dogs',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'La Cucina di Nava',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '07666',
#   'categories': 'Italian',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': "Epstein's Of Yonkers",
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10710',
#   'categories': 'Delis, Kosher, American',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Zula Grill',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '07631',
#   'categories': 'Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Falafel Place',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '10710',
#   'categories': 'Falafel, Vegetarian',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': "Mario's Restaurant",
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10458',
#   'categories': 'Italian, Seafood',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Chop Chop',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10033',
#   'categories': 'Kosher, Chinese, Sushi Bars',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'S & S Kosher Restaurant',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '07631',
#   'categories': 'Restaurants',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': "Louie's Dale Diner",
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10463',
#   'categories': 'Diners, Breakfast & Brunch, Burgers',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Sababa Grill',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '07666',
#   'categories': 'Middle Eastern',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Cheburechnaya',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11374',
#   'categories': 'Kosher, Russian, Uzbek',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': "Kin'd",
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '11366',
#   'categories': 'Thai',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'The Pureganic Cafe',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '10528',
#   'categories': 'Vegan, Gluten-Free, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Five Guys',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10803',
#   'categories': 'Burgers, Fast Food, Hot Dogs',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Pizza Fenice',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10803',
#   'categories': 'Pizza',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Beli Restaurant',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10031',
#   'categories': 'Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Yalla Teaneck',
#   'rating': 4.0,
#   'price': 'Not Available',
#   'zip_code': '07666',
#   'categories': 'Kosher, Middle Eastern, Mediterranean',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Djerdan Burek Astoria',
#   'rating': 4.0,
#   'price': '$$',
#   'zip_code': '11106',
#   'categories': 'Turkish, Modern European',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Court Deli',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '10451',
#   'categories': 'Delis, Desserts, Breakfast & Brunch',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Malka NYC',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10023',
#   'categories': 'Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Eden Wok',
#   'rating': 2.0,
#   'price': '$$',
#   'zip_code': '10804',
#   'categories': 'Chinese, American',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Happy Daze Caribbean Juice bar',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '10458',
#   'categories': 'Juice Bars & Smoothies, Acai Bowls, Caribbean',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Cocina Burger Shop',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'zip_code': '10705',
#   'categories': 'Burgers',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'City Vineyard',
#   'rating': 4.0,
#   'price': '$$$',
#   'zip_code': '10013',
#   'categories': 'Wine Bars, New American, Venues & Event Spaces',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Tabernacle Steakhouse',
#   'rating': 4.0,
#   'price': '$$$$',
#   'zip_code': '10018',
#   'categories': 'Steakhouses, Kosher, Venues & Event Spaces',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Grill Time',
#   'rating': 3.5,
#   'price': '$$',
#   'zip_code': '11021',
#   'categories': 'Kosher, Middle Eastern',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'By the Way Bakery',
#   'rating': 4.5,
#   'price': '$$',
#   'zip_code': '10706',
#   'categories': 'Bakeries, Gluten-Free, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'},
#  {'name': 'Vegan Pastry Lab',
#   'rating': 5.0,
#   'price': 'Not Available',
#   'zip_code': '07631',
#   'categories': 'Vegan, Bakeries, Kosher',
#   'cuisine': 'Kosher',
#   'borough': 'The Bronx, NY'}]

# %%
from src.restaurant_analysis.rest_summary import summarize_restaurants  
import pandas as pd

# Specify the path to your CSV file
csv_file_path = 'restaurants_data.csv'

# Call the summarize_restaurants function
restaurant_summary = summarize_restaurants(csv_file_path)

# Display the summary
for key, value in restaurant_summary.items():
    print(f"{key}:")
    if isinstance(value, pd.Series):
        display(value)  # More visually appealing display for Pandas Series
    else:
        print(value)
    print()  # Add a newline for better separation
# Out:
# Number of Restaurants:
# 1000
#
# Average Rating:
# 4.154
#
# Cuisine Distribution:
# Italian     200
# American    200
# Japanese    200
# Mexican     200
# Kosher      200
# Name: cuisine, dtype: int64
# Borough Distribution:
# Brooklyn, NY         250
# Queens, NY           250
# Staten Island, NY    250
# The Bronx, NY        250
# Name: borough, dtype: int64

# %%
from src.restaurant_analysis.rest_summary import DataSummary  
# Read the CSV file into a DataFrame
df_restaurants = pd.read_csv('restaurants_data.csv')

# Create an instance of the DataSummary class
data_summary = DataSummary(df_restaurants)

# Display the first and last five rows of the data
print("\nFirst 5 columns:")
data_summary.display_head()
print("\nLast 5 columns:")
data_summary.display_tail()

# Get the shape of the data
print(f"Data Shape: {data_summary.get_shape()}")
# Out:
# First 5 columns:
#                   name  rating price  zip_code  \
# 0     Osteria Brooklyn     4.5   $$$     11205
# 1  Forma Pasta Factory     4.5    $$     11238
# 2              Evelina     4.5    $$     11205
# 3    Piccoli Trattoria     4.5    $$     11215
# 4  Positano Restaurant     4.5   $$$     11209
#
#                         categories  cuisine       borough
# 0                          Italian  Italian  Brooklyn, NY
# 1      Italian, Pasta Shops, Salad  Italian  Brooklyn, NY
# 2                          Italian  Italian  Brooklyn, NY
# 3  Italian, Pasta Shops, Wine Bars  Italian  Brooklyn, NY
# 4    Italian, Gluten-Free, Seafood  Italian  Brooklyn, NY
# Last 5 columns:
#                       name  rating          price  zip_code  \
# 995          City Vineyard     4.0            $$$     10013
# 996  Tabernacle Steakhouse     4.0           $$$$     10018
# 997             Grill Time     3.5             $$     11021
# 998      By the Way Bakery     4.5             $$     10706
# 999       Vegan Pastry Lab     5.0  Not Available      7631
#
#                                          categories cuisine        borough
# 995  Wine Bars, New American, Venues & Event Spaces  Kosher  The Bronx, NY
# 996      Steakhouses, Kosher, Venues & Event Spaces  Kosher  The Bronx, NY
# 997                          Kosher, Middle Eastern  Kosher  The Bronx, NY
# 998                   Bakeries, Gluten-Free, Kosher  Kosher  The Bronx, NY
# 999                         Vegan, Bakeries, Kosher  Kosher  The Bronx, NY
# Data Shape: (1000, 7)

# %%
from src.restaurant_analysis.rest_analysis import ExploratoryDataAnalysis

# Create an instance of ExploratoryDataAnalysis
eda = ExploratoryDataAnalysis(df_restaurants)

# Unique cuisines
unique_cuisines = eda.unique_cuisines()
print(f"Unique Cuisines: {unique_cuisines}")
# Out:
# Unique Cuisines: ['Italian' 'American' 'Japanese' 'Mexican' 'Kosher']

# %%
# Cuisine value counts
cuisine_counts = eda.cuisine_value_counts()
print("\nCuisine Counts:")
print(cuisine_counts)
# Out:
# Cuisine Counts:
# Italian     200
# American    200
# Japanese    200
# Mexican     200
# Kosher      200
# Name: cuisine, dtype: int64

# %%
# Unique boroughs
unique_boroughs = eda.unique_boroughs()
print(f"\nUnique Boroughs: {unique_boroughs}")
# Out:
# Unique Boroughs: ['Brooklyn, NY' 'Queens, NY' 'Staten Island, NY' 'The Bronx, NY']

# %%
# Borough value counts
borough_counts = eda.borough_value_counts()
print("\nBorough Counts:")
print(borough_counts)
# Out:
# Borough Counts:
# Brooklyn, NY         250
# Queens, NY           250
# Staten Island, NY    250
# The Bronx, NY        250
# Name: borough, dtype: int64

# %%
# Create an instance of ExploratoryDataAnalysis with your DataFrame
eda = ExploratoryDataAnalysis(df_restaurants)

# Average rating by cuisine
avg_rating_cuisine = eda.average_rating_by_category('cuisine')
print("Average Rating by Cuisine:\n", avg_rating_cuisine)
# Out:
# Average Rating by Cuisine:
#  cuisine
# American    4.1750
# Italian     4.1875
# Japanese    4.2375
# Kosher      4.0725
# Mexican     4.0975
# Name: rating, dtype: float64

# %%
# Average price level by cuisine
avg_price_cuisine = eda.average_price_by_category('cuisine')
print("\nAverage Price Level by Cuisine:\n", avg_price_cuisine)
# Out:
# Average Price Level by Cuisine:
#  cuisine
# American    4.900
# Italian     4.010
# Japanese    5.830
# Kosher      5.265
# Mexican     5.165
# Name: price_level, dtype: float64

# %%
# Histogram of Ratings
eda.plot_rating_distribution()

# %%
# Count Plot for Cuisines
eda.plot_cuisine_count()

# %%
# Correlation Analysis (if applicable)
eda.correlation_analysis()
# Out:
# /Users/mapalo/Documents/GitHub/goodrestaurants/src/restaurant_analysis/rest_analysis.py:223: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = self.data.corr()

# %% [markdown]
# ## Inference <a id="inf"></a>

# %%
from src.restaurant_analysis.rest_inference import Inference  
# Create an instance of Inference
inference = Inference(df_restaurants)
# Get statistical summary of ratings
rating_summary = inference.statistical_summary('rating')
print("\nStatistical Summary - Ratings:")
print(rating_summary)
# Out:
# Statistical Summary - Ratings:
# count    1000.000000
# mean        4.154000
# std         0.464219
# min         2.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.500000
# max         5.000000
# Name: rating, dtype: float64

# %%
# Correlation Analysis
correlation_result = inference.correlation_analysis()
print("\nCorrelation between Rating and Price Level:", correlation_result)

# Add more calls to other methods as needed
# Out:
# Correlation between Rating and Price Level: -0.27577814020196695

# %%
# Conduct hypothesis test on ratings across different cuisines
anova_results = inference.hypothesis_test_rating_cuisine()
print("ANOVA Test - Rating by Cuisine:", anova_results)
# Out:
# ANOVA Test - Rating by Cuisine: {'F-Statistic': 4.318829450404045, 'p-value': 0.0018121040701858146}

# %%
# Chi-Square Test
chi_square_result = inference.chi_square_test('cuisine', 'borough')
print("Chi-Square Test - Cuisine vs Borough:", chi_square_result)
# Out:
# Chi-Square Test - Cuisine vs Borough: {'Chi-Square Statistic': 0.0, 'p-value': 1.0}

# %%
# Box Plot - Ratings by Cuisine
inference.boxplot_rating_by_category('cuisine')

# %%
# Box Plot - Ratings by Borough
inference.boxplot_rating_by_category('borough')

# %%
# Kruskal-Wallis Test
kruskal_result = inference.kruskal_wallis_test('cuisine')
print("\nKruskal-Wallis Test - Rating by Cuisine:", kruskal_result)
# Out:
# Kruskal-Wallis Test - Rating by Cuisine: {'H-Statistic': 13.760159925222297, 'p-value': 0.0081012094692964}

# %%
# Scatter plot Rating vs Price
inference.scatter_plot_rating_price()

# %% [markdown]
# ## Data Preparation <a id="data-preparation"></a>

# %% [markdown]
# #### Data Preparation:
# - Addressed data integrity and usability issues identified during EDA.
# - Employed Pandas for data cleaning, handling missing values, outliers, and ensuring consistency

# %% [markdown]
# ## Prepped Data Review <a id="prepped-data-review"></a>

# %% [markdown]
# ## Investigative Analysis & Results <a id="investigative-analysis-results"></a>

# %% [markdown]
# ## Conclusions <a id="conclusions"></a>

# %%
from src.restaurant_analysis.rest_analysis import Scrape
#a = Scrape('https://www.census.gov/quickfacts/fact/table/richmondcountynewyork,bronxcountynewyork,queenscountynewyork,kingscountynewyork,newyorkcountynewyork/RHI825222#RHI825222')
b = Scrape('https://www.census.gov/quickfacts/fact/table/richmondcountynewyork,bronxcountynewyork,queenscountynewyork,kingscountynewyork,newyorkcountynewyork/RHI825222#RHI825222')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb Cell 53 line 3
#       <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> from src.restaurant_analysis.rest_analysis import Scrape
#       <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a> #a = Scrape('https://www.census.gov/quickfacts/fact/table/richmondcountynewyork,bronxcountynewyork,queenscountynewyork,kingscountynewyork,newyorkcountynewyork/RHI825222#RHI825222')
# ----> <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y102sZmlsZQ%3D%3D?line=2'>3</a> b = Scrape('https://www.census.gov/quickfacts/fact/table/richmondcountynewyork,bronxcountynewyork,queenscountynewyork,kingscountynewyork,newyorkcountynewyork/RHI825222#RHI825222')
#
# File ~/Documents/GitHub/goodrestaurants/src/restaurant_analysis/rest_analysis.py:31, in Scrape.__init__(self, websiteurl)
#      25 def __init__(self, websiteurl):
#      26     """
#      27     Args:
#      28         websiteurl(str): url of chosen website
#      29     Returns:
#      30         landing of tabular data in pandas dataframe """
# ---> 31     self.df = pd.read_html(websiteurl)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1201 validate_header_arg(header)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/html.py:982, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     980 retained = None
#     981 for flav in flavor:
# --> 982     parser = _parser_dispatch(flav)
#     983     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     985     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/html.py:939, in _parser_dispatch(flavor)
#     937 else:
#     938     if not _HAS_LXML:
# --> 939         raise ImportError("lxml not found, please install it")
#     940 return _valid_parsers[flavor]
#
# ImportError: lxml not found, please install it

# %%
#create pandas dataframe object from html reader
#race = a.reader()
dfboroughs = b.reader()
dfboroughs
# Out:
#                                            Population  Unnamed: 1  \
# 0         Population Estimates, July 1, 2022, (V2022)   491,133
# 1   Population estimates base, April 1, 2020, (V2022)   495,749
# 2   Population, percent change - April 1, 2020 (es...     -0.9%
# 3                   Population, Census, April 1, 2020      495747
# 4                   Population, Census, April 1, 2010      468730
# 5                                         Age and Sex         NaN
# 6                      Persons under 5 years, percent      5.3%
# 7                     Persons under 18 years, percent     21.3%
# 8                  Persons 65 years and over, percent     17.4%
# 9                             Female persons, percent     50.9%
# 10                           Race and Hispanic Origin         NaN
# 11                               White alone, percent     71.4%
# 12        Black or African American alone, percent(a)     11.6%
# 13  American Indian and Alaska Native alone, perce...      0.7%
# 14                            Asian alone, percent(a)     13.7%
# 15  Native Hawaiian and Other Pacific Islander alo...      0.1%
# 16                         Two or More Races, percent      2.4%
# 17                     Hispanic or Latino, percent(b)     18.8%
# 18       White alone, not Hispanic or Latino, percent     56.6%
# 19                         Population Characteristics         NaN
# 20                                Veterans, 2018-2022       11522
# 21           Foreign born persons, percent, 2018-2022       24.8%
# 22                                            Housing         NaN
# 23               Housing units, July 1, 2022, (V2022)      184530
# 24        Owner-occupied housing unit rate, 2018-2022       68.6%
# 25  Median value of owner-occupied housing units, ...    $637,100
# 26  Median selected monthly owner costs -with a mo...      $2,865
# 27  Median selected monthly owner costs -without a...      $1,049
# 28                       Median gross rent, 2018-2022      $1,602
# 29                             Building permits, 2022         392
# 30                     Families & Living Arrangements         NaN
# 31                              Households, 2018-2022      170000
# 32                   Persons per household, 2018-2022        2.86
# 33  Living in same house 1 year ago, percent of pe...       94.0%
# 34  Language other than English spoken at home, pe...       34.8%
# 35                          Computer and Internet Use         NaN
# 36     Households with a computer, percent, 2018-2022       94.0%
# 37  Households with a broadband Internet subscript...       88.1%
# 38                                          Education         NaN
# 39  High school graduate or higher, percent of per...       88.7%
# 40  Bachelor's degree or higher, percent of person...       35.3%
# 41                                             Health         NaN
# 42  With a disability, under age 65 years, percent...        6.5%
# 43  Persons without health insurance, under age 65...      4.9%
# 44                                            Economy         NaN
# 45  In civilian labor force, total, percent of pop...       59.9%
# 46  In civilian labor force, female, percent of po...       54.6%
# 47  Total accommodation and food services sales, 2...      665440
# 48  Total health care and social assistance receip...     3540659
# 49  Total transportation and warehousing receipts/...     1091017
# 50               Total retail sales, 2017 ($1,000)(c)     4302741
# 51             Total retail sales per capita, 2017(c)      $9,043
# 52                                     Transportation         NaN
# 53  Mean travel time to work (minutes), workers ag...        43.8
# 54                                   Income & Poverty         NaN
# 55  Median household income (in 2022 dollars), 201...     $96,185
# 56  Per capita income in past 12 months (in 2022 d...     $43,199
# 57                        Persons in poverty, percent     11.9%
#
#       Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5
# 0    1,379,946   2,278,029   2,590,516   1,596,273
# 1    1,472,656   2,405,464   2,736,075   1,694,250
# 2        -6.3%       -5.3%       -5.3%       -5.8%
# 3        1472654       2405464       2736074       1694251
# 4        1385108       2230722       2504700       1585873
# 5            NaN           NaN           NaN           NaN
# 6         6.6%        5.4%        6.4%        4.2%
# 7        24.3%       19.4%       22.1%       14.0%
# 8        14.4%       18.0%       15.6%       18.4%
# 9        52.7%       51.1%       52.3%       52.2%
# 10           NaN           NaN           NaN           NaN
# 11       43.6%       46.5%       49.6%       62.9%
# 12       44.3%       20.8%       33.2%       18.7%
# 13        3.1%        1.4%        1.0%        1.3%
# 14        4.8%       27.9%       13.2%       13.3%
# 15        0.4%        0.2%        0.1%        0.2%
# 16        3.8%        3.1%        2.9%        3.6%
# 17       56.6%       28.2%       18.9%       26.2%
# 18        8.7%       23.9%       36.7%       45.5%
# 19           NaN           NaN           NaN           NaN
# 20         23482         38515         33841         27778
# 21         33.9%         47.1%         35.3%         28.1%
# 22           NaN           NaN           NaN           NaN
# 23        558005        911957       1101441        923302
# 24         20.0%         45.2%         30.3%         24.3%
# 25      $501,400      $677,700      $865,300    $1,104,000
# 26        $2,903        $2,977        $3,359       $4,000+
# 27          $949        $1,042        $1,057        $1,367
# 28        $1,401        $1,847        $1,715        $2,024
# 29          3930          5161          9423          2584
# 30           NaN           NaN           NaN           NaN
# 31        525387        816859        997957        772601
# 32          2.64          2.85          2.64          2.04
# 33         92.0%         92.1%         90.2%         83.4%
# 34         58.0%         55.4%         44.2%         38.1%
# 35           NaN           NaN           NaN           NaN
# 36         91.6%         94.2%         91.5%         93.9%
# 37         83.6%         89.2%         86.3%         89.5%
# 38           NaN           NaN           NaN           NaN
# 39         74.5%         82.8%         83.8%         88.5%
# 40         21.2%         34.8%         40.4%         62.8%
# 41           NaN           NaN           NaN           NaN
# 42         11.9%          5.8%          6.0%          6.8%
# 43        8.3%        9.6%        7.1%        5.4%
# 44           NaN           NaN           NaN           NaN
# 45         58.3%         63.6%         63.7%         66.5%
# 46         54.7%         58.2%         60.1%         62.7%
# 47       1418743       4593736       4361700      27902302
# 48      13367520      15735791      20989493      44469833
# 49       1163686      20371315       2409494       4764857
# 50       9150286      19297120      28734814      54824853
# 51        $6,355        $8,408       $11,076       $33,587
# 52           NaN           NaN           NaN           NaN
# 53          44.6          43.6          42.7          31.8
# 54           NaN           NaN           NaN           NaN
# 55       $47,036       $82,431       $74,692       $99,880
# 56       $25,845       $39,201       $43,165       $89,702
# 57       26.4%       13.6%       19.2%       17.4%

# %% [markdown]
# Only several predictors are included for analysis

# %%
import pandas as pd
dfboroughs = pd.read_csv('boroughs_data.csv')
dfboroughs.head()
# Out:
#    Unnamed: 0                                         Population  Unnamed: 1  \
# 0           0        Population Estimates, July 1, 2022, (V2022)   491,133
# 1           1  Population estimates base, April 1, 2020, (V2022)   495,749
# 2           2  Population, percent change - April 1, 2020 (es...     -0.9%
# 3           3                  Population, Census, April 1, 2020      495747
# 4           4                  Population, Census, April 1, 2010      468730
#
#      Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5
# 0   1,379,946   2,278,029   2,590,516   1,596,273
# 1   1,472,656   2,405,464   2,736,075   1,694,250
# 2       -6.3%       -5.3%       -5.3%       -5.8%
# 3       1472654       2405464       2736074       1694251
# 4       1385108       2230722       2504700       1585873

# %%
predictors =  ['Population Estimates, July 1, 2022, (V2022)', 'White alone, not Hispanic or Latino, percent', 'Foreign born persons, percent, 2018-2022', 'Median household income (in 2022 dollars), 2018-2022']
#creating a a dataframe from quering a virtual table of our scraped data. creating location variable to join with 

dfboroughs.query('Population in ("Population Estimates, July 1, 2022, (V2022)", "White alone, not Hispanic or Latino, percent", "Foreign born persons, percent, 2018-2022", "Median household income (in 2022 dollars), 2018-2022")').copy().reset_index()
# Out:
#    index  Unnamed: 0                                         Population  \
# 0      0           0        Population Estimates, July 1, 2022, (V2022)
# 1     18          18       White alone, not Hispanic or Latino, percent
# 2     21          21           Foreign born persons, percent, 2018-2022
# 3     55          55  Median household income (in 2022 dollars), 201...
#
#    Unnamed: 1    Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5
# 0   491,133   1,379,946   2,278,029   2,590,516   1,596,273
# 1     56.6%        8.7%       23.9%       36.7%       45.5%
# 2       24.8%         33.9%         47.1%         35.3%         28.1%
# 3     $96,185       $47,036       $82,431       $74,692       $99,880

# %%
predictors =  ['Population Estimates, July 1, 2022, (V2022)', 'White alone, not Hispanic or Latino, percent', 'Foreign born persons, percent, 2018-2022', 'Median household income (in 2022 dollars), 2018-2022']

# %%
dfboroughs.to_csv('boroughs_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb Cell 59 line 1
# ----> <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y112sZmlsZQ%3D%3D?line=0'>1</a> dfboroughs.to_csv('boroughs_data.csv')
#
# NameError: name 'dfboroughs' is not defined

# %%
import pandas as pd
rests = pd.read_csv('restaurants_data.csv')
rests.head()
# Out:
#                  name  rating          price  zip_code  \
# 0   Piccoli Trattoria     4.5             $$     11215
# 1    Osteria Brooklyn     4.5            $$$     11205
# 2  Barbalu - Brooklyn     4.5  Not Available     11201
# 3           Cent'Anni     4.0             $$     11238
# 4        Ammazzacaffè     4.5             $$     11211
#
#                           categories  cuisine       borough
# 0    Italian, Pasta Shops, Wine Bars  Italian  Brooklyn, NY
# 1                            Italian  Italian  Brooklyn, NY
# 2               Italian, Pizza, Bars  Italian  Brooklyn, NY
# 3                            Italian  Italian  Brooklyn, NY
# 4  Cocktail Bars, Italian, Wine Bars  Italian  Brooklyn, NY

# %%
manhattan_zip_codes = ['10001', '10002', '10003', '10004', '10005',
    '10006', '10007', '10009', '10010', '10011',
    '10012', '10013', '10014', '10016', '10017',
    '10018', '10019', '10020', '10021', '10022',
    '10023', '10024', '10025', '10026', '10027',
    '10028', '10029', '10030', '10031', '10032',
    '10033', '10034', '10035', '10036', '10037',
    '10038', '10039', '10040', '10128', '10280']

brooklyn_zip_codes = ['11201', '11203', '11204', '11205', '11206',
    '11207', '11208', '11209', '11210', '11211',
    '11212', '11213', '11214', '11215', '11216',
    '11217', '11218', '11219', '11220', '11221',
    '11222', '11223', '11224', '11225', '11226',
    '11228', '11229', '11230', '11231', '11232',
    '11233', '11234', '11235', '11236', '11237',
    '11238', '11239', '11249']

queens_zip_codes = ['11001', '11004', '11101', '11102', '11103',
    '11104', '11105', '11106', '11354', '11355',
    '11356', '11357', '11358', '11359', '11360',
    '11361', '11362', '11363', '11364', '11365',
    '11366', '11367', '11368', '11369', '11370',
    '11371', '11372', '11373', '11374', '11375',
    '11377', '11378', '11379', '11385', '11411',
    '11412', '11413', '11414', '11415', '11416',
    '11417', '11418', '11419', '11420', '11421',
    '11422', '11423', '11426', '11427', '11428',
    '11429', '11430', '11432', '11433', '11434',
    '11435', '11436', '11691', '11692', '11693',
    '11694', '11697']

staten_island_zip_codes = ['10301', '10302', '10303', '10304', '10305',
    '10306', '10307', '10308', '10309', '10310',
    '10311', '10312', '10314']

bronx_zip_codes = ['10451', '10452', '10453', '10454', '10455',
    '10456', '10457', '10458', '10459', '10460',
    '10461', '10462', '10463', '10464', '10465',
    '10466', '10467', '10468', '10469', '10470',
    '10471', '10472', '10473', '10474', '10475']

# %%
rests['where'] = rests.apply(lambda row: 'Manhattan' if str(row['zip_code']).strip() in manhattan_zip_codes
else ('Brooklyn' if str(row['zip_code']).strip() in brooklyn_zip_codes
else ('Queens' if str(row['zip_code']).strip() in queens_zip_codes
else ('The Bronx' if str(row['zip_code']).strip() in bronx_zip_codes
else ('Staten Island' if str(row['zip_code']).strip() in staten_island_zip_codes
else 'other')))), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb Cell 62 line 1
# ----> <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y115sZmlsZQ%3D%3D?line=0'>1</a> rests['where'] = rests.apply(lambda row: 'Manhattan' if str(row['zip_code']).strip() in manhattan_zip_codes
#       <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y115sZmlsZQ%3D%3D?line=1'>2</a> else ('Brooklyn' if str(row['zip_code']).strip() in brooklyn_zip_codes
#       <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y115sZmlsZQ%3D%3D?line=2'>3</a> else ('Queens' if str(row['zip_code']).strip() in queens_zip_codes
#       <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y115sZmlsZQ%3D%3D?line=3'>4</a> else ('The Bronx' if str(row['zip_code']).strip() in bronx_zip_codes
#       <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y115sZmlsZQ%3D%3D?line=4'>5</a> else ('Staten Island' if str(row['zip_code']).strip() in staten_island_zip_codes
#       <a href='vscode-notebook-cell:/Users/mapalo/Documents/GitHub/goodrestaurants/restaurants_analysis.ipynb#Y115sZmlsZQ%3D%3D?line=5'>6</a> else 'other')))), axis=1)
#
# NameError: name 'rests' is not defined

# %%
rests = rests[rests['where'] != 'other'].reset_index(drop=True)
# Out:
# (116, 8)

# %%
rests = rests[rests['price'] != 'Not Available'].reset_index(drop=True)

# %%
rests[rests['where'] == 'other']
# Out:
# Empty DataFrame
# Columns: [name, rating, price, zip_code, categories, cuisine, borough, where]
# Index: []

# %%
rests.shape
# Out:
# (650, 8)

# %%
rests.to_csv('new_rests_data.csv')
