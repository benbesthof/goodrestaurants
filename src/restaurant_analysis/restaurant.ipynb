# %%
# Import the function from the yelpapi.py script
from yelpapi import get_restaurant_data

# Define the location and list of cuisines
location = 'New York, NY'  
cuisines = ['Italian', 'American', 'Japanese', 'Mexican', 'Kosher']  # Desired cuisines

# Call the function with the desired parameters
restaurant_data = get_restaurant_data(location, cuisines)

# Display the results
for restaurant in restaurant_data:
    print(f"Name: {restaurant['name']}, Cuisine: {restaurant['cuisine']}, Rating: {restaurant['rating']}, Price: {restaurant['price']}")
# Out:
# Name: Da Andrea - Greenwich Village, Cuisine: Italian, Rating: 4.5, Price: $$
# Name: Olio e Più, Cuisine: Italian, Rating: 4.5, Price: $$
# Name: Rubirosa, Cuisine: Italian, Rating: 4.5, Price: $$
# Name: Paesano of Mulberry Street, Cuisine: Italian, Rating: 4.0, Price: $$
# Name: Barbalu - Brooklyn, Cuisine: Italian, Rating: 4.5, Price: Not Available
# Name: Botte Brooklyn, Cuisine: Italian, Rating: 4.5, Price: Not Available
# Name: L'Artusi, Cuisine: Italian, Rating: 4.5, Price: $$$
# Name: Trapizzino, Cuisine: Italian, Rating: 4.5, Price: $$
# Name: Lillo Cucina Italiana, Cuisine: Italian, Rating: 5.0, Price: $$
# Name: Piccola Cucina Osteria, Cuisine: Italian, Rating: 4.5, Price: $$
# Name: Carlotto, Cuisine: Italian, Rating: 4.5, Price: Not Available
# Name: Gelso & Grand, Cuisine: Italian, Rating: 4.5, Price: $$
# Name: Risotteria Melotti NYC, Cuisine: Italian, Rating: 4.5, Price: $$
# Name: Cecconi's Dumbo, Cuisine: Italian, Rating: 3.5, Price: $$$
# ...

# %%
restaurant_data
# Out:
# [{'name': 'Da Andrea - Greenwich Village',
#   'rating': 4.5,
#   'price': '$$',
#   'categories': ['Italian', 'Mediterranean', 'Breakfast & Brunch'],
#   'cuisine': 'Italian'},
#  {'name': 'Olio e Più',
#   'rating': 4.5,
#   'price': '$$',
#   'categories': ['Pizza', 'Italian', 'Cocktail Bars'],
#   'cuisine': 'Italian'},
#  {'name': 'Rubirosa',
#   'rating': 4.5,
#   'price': '$$',
#   'categories': ['Italian', 'Pizza'],
#   'cuisine': 'Italian'},
#  {'name': 'Paesano of Mulberry Street',
#   'rating': 4.0,
#   'price': '$$',
#   'categories': ['Italian', 'Salad', 'Seafood'],
#   'cuisine': 'Italian'},
#  {'name': 'Barbalu - Brooklyn',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'categories': ['Italian', 'Pizza', 'Bars'],
#   'cuisine': 'Italian'},
#  {'name': 'Botte Brooklyn',
#   'rating': 4.5,
#   'price': 'Not Available',
#   'categories': ['Italian', 'Pizza'],
#   'cuisine': 'Italian'},
#  {'name': "L'Artusi",
#   'rating': 4.5,
#   'price': '$$$',
# ...

# %%
restaurant
# Out:
# {'name': 'Reunion',
#  'rating': 4.5,
#  'price': '$$',
#  'categories': ['Breakfast & Brunch', 'Middle Eastern', 'Cocktail Bars'],
#  'cuisine': 'Kosher'}
